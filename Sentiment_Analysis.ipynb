# %% [markdown]
# <a href="https://colab.research.google.com/github/Arch0/Sentiment-Analysis-of-hotel-review/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis of hotel reviews

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Data Analyst - Test Data.csv",encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#                                               Review  ... Unnamed: 3
# 0  I was very impressed with the resort.\n Great ...  ...        NaN
# 1  The rooms were nice the outside needs work als...  ...        NaN
# 2  Great location! I have stayed at this hotel on...  ...        NaN
# 3  The hotel was adequate for my stay. The strips...  ...        NaN
# 4  Great location, room was large and spacious. P...  ...        NaN
#
# [5 rows x 4 columns]

# %%
train = df[df['date'] < '20190710']
test = df[df['date'] > '20190820']

# %%
# Removing punctuations
data=train.iloc[:,0]
data.replace("[^a-zA-Z]"," ",regex=True, inplace=True)

# %%
# Convertng Reviews to lower case
data=data.str.lower()
data
# Out:
# 0       i was very impressed with the resort   great s...
# 1       the rooms were nice the outside needs work als...
# 2       great location  i have stayed at this hotel on...
# 3       the hotel was adequate for my stay  the strips...
# 4       great location  room was large and spacious  p...
#                               ...
# 6443     the staff were all so friendly  frank  the ch...
# 6444            the internet barely worked or didn t work
# 6445     the location was great            the bed was...
# 6446     we were early for check in and the staff was ...
# 6447     staff  free coffee  location and activities  ...
# Name: Review, Length: 5799, dtype: object

# %%
reviews=[]
reviews.append(" ".join(str(x) for x in data))

# %%
reviews
# Out:
# ['i was very impressed with the resort   great staff at the main resort pool bar  we had a blast with them   clean  professional staff  great location and very reasonable       read more   read less the rooms were nice the outside needs work also no free breakfast it would have been nice overall it was ok      read more   read less great location  i have stayed at this hotel on my last three trips to new york       read more   read less the hotel was adequate for my stay  the strips in the bathtub were useless as i fell while taking a shower  i asked the front desk staff several times to get a bath mat but they never did  management was unresponsive to my request which was very poor  someone should have gone to a dollar store and gotten a bath mat  breakfast was good but it would have been nice to have had yogurt and or cottage cheese on the buffet       read more   read less great location  room was large and spacious  parking was easy and we appreciated the friendly staff      read
# ...

# %%
reviews[0]
# Out:
# 'i was very impressed with the resort   great staff at the main resort pool bar  we had a blast with them   clean  professional staff  great location and very reasonable       read more   read less the rooms were nice the outside needs work also no free breakfast it would have been nice overall it was ok      read more   read less great location  i have stayed at this hotel on my last three trips to new york       read more   read less the hotel was adequate for my stay  the strips in the bathtub were useless as i fell while taking a shower  i asked the front desk staff several times to get a bath mat but they never did  management was unresponsive to my request which was very poor  someone should have gone to a dollar store and gotten a bath mat  breakfast was good but it would have been nice to have had yogurt and or cottage cheese on the buffet       read more   read less great location  room was large and spacious  parking was easy and we appreciated the friendly staff      read 
# ...

# %%
reviews=str(reviews)

# %%
from wordcloud import WordCloud
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
wordcloud = WordCloud().generate(reviews)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# The most used hotel related words in hotel analysis are hotel, room, bed, pool, bathroom, desk, clean, great, resturant.
